# %% [markdown]
# # 2 データ整形と前処理

# %%
import pandas as pd

# %% [markdown]
# ## 前処理するデータの年を入力

# %%
targeｔ_year = '2019'

# %% [markdown]
# ## 生データ読み込み

# %%
read_file_name = target_year + '_result_combined_raw.pickle'
results  = pd.read_pickle(read_file_name)

# %%
results
# Out:
#               着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム     着差     単勝  \
# 201901010101   1   1   1      ゴルコンダ  牡2  54.0  ルメール  1:48.3    NaN    1.4
# 201901010101   2   3   3   プントファイヤー  牡2  54.0  岩田康誠  1:50.1      大    3.5
# 201901010101   3   4   4  ラグリマスネグラス  牡2  51.0  団野大成  1:50.9      5   46.6
# 201901010101   4   8   9     キタノコドウ  牡2  51.0  菅原明良  1:51.5  3.1/2   56.8
# 201901010101   5   5   5   ネモフィラブルー  牡2  54.0  川島信二  1:51.7  1.1/2  140.3
# ...           ..  ..  ..        ...  ..   ...   ...     ...    ...    ...
# 201910021212  12   6  11   スリープレッピー  セ6  56.0  森裕太朗  2:45.7    1/2  120.3
# 201910021212  13   1   1    バリオラージュ  牡5  54.0   斎藤新  2:46.0  1.3/4    7.5
# 201910021212  14   2   3  サンライズアミーゴ  牡4  54.0  亀田温心  2:46.2      1   99.2
# 201910021212  15   6  12        トロハ  牝3  52.0    武豊  2:46.2     クビ   17.5
# 201910021212  16   2   4   ダイシンステルラ  牝4  55.0  川須栄彦  2:47.0      5  110.3
#
#                 人気       馬体重       調教師 course_len weather race_type  \
# ...

# %% [markdown]
# ### 着順データの降着や中止のものを削除

# %%
results2 = results[~results['着順'].astype(str).str.contains('\D')]

# %%
results2.columns
# Out:
# Index(['着順', '枠番', '馬番', '馬名', '性齢', '斤量', '騎手', 'タイム', '着差', '単勝', '人気',
#        '馬体重', '調教師', 'course_len', 'weather', 'race_type', 'ground_state',
#        'date'],
#       dtype='object')

# %% [markdown]
# ### 性齢データを性と年齢に分ける

# %%
results2['性齢'].value_counts()
# Out:
# 牡3     9986
# 牝3     9110
# 牡2     4815
# 牡4     4287
# 牝2     3623
# 牡5     3426
# 牝4     3364
# 牝5     2100
# 牡6     1865
# 牡7      941
# 牝6      718
# セ4      473
# セ5      465
# セ3      439
# セ6      435
# 牡8      383
# セ7      202
# 牝7      149
# 牡9       82
# セ8       79
# セ2       69
# 牝8       59
# 牡10      22
# 牝10       7
# セ9        7
# セ10       5
# セ11       3
# 牡11       2
# セ12       2
# Name: 性齢, dtype: int64

# %%
results２['性'] = results2['性齢'].map(lambda x: str(x)[0])
# Out:
# /var/folders/p9/g996fg895cs0zrq0v3h2273m0000gn/T/ipykernel_35932/3717592640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results２['性'] = results2['性齢'].map(lambda x: str(x)[0])

# %%
results2
# Out:
#               着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム     着差     単勝  \
# 201901010101   1   1   1      ゴルコンダ  牡2  54.0  ルメール  1:48.3    NaN    1.4
# 201901010101   2   3   3   プントファイヤー  牡2  54.0  岩田康誠  1:50.1      大    3.5
# 201901010101   3   4   4  ラグリマスネグラス  牡2  51.0  団野大成  1:50.9      5   46.6
# 201901010101   4   8   9     キタノコドウ  牡2  51.0  菅原明良  1:51.5  3.1/2   56.8
# 201901010101   5   5   5   ネモフィラブルー  牡2  54.0  川島信二  1:51.7  1.1/2  140.3
# ...           ..  ..  ..        ...  ..   ...   ...     ...    ...    ...
# 201910021212  12   6  11   スリープレッピー  セ6  56.0  森裕太朗  2:45.7    1/2  120.3
# 201910021212  13   1   1    バリオラージュ  牡5  54.0   斎藤新  2:46.0  1.3/4    7.5
# 201910021212  14   2   3  サンライズアミーゴ  牡4  54.0  亀田温心  2:46.2      1   99.2
# 201910021212  15   6  12        トロハ  牝3  52.0    武豊  2:46.2     クビ   17.5
# 201910021212  16   2   4   ダイシンステルラ  牝4  55.0  川須栄彦  2:47.0      5  110.3
#
#                 人気       馬体重       調教師 course_len weather race_type  \
# ...

# %%
results２['年齢'] = results2['性齢'].map(lambda x: str(x)[1:])
# Out:
# /var/folders/p9/g996fg895cs0zrq0v3h2273m0000gn/T/ipykernel_35932/1489994830.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results２['年齢'] = results2['性齢'].map(lambda x: str(x)[1:])

# %%
results2
# Out:
#               着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム     着差     単勝  \
# 201901010101   1   1   1      ゴルコンダ  牡2  54.0  ルメール  1:48.3    NaN    1.4
# 201901010101   2   3   3   プントファイヤー  牡2  54.0  岩田康誠  1:50.1      大    3.5
# 201901010101   3   4   4  ラグリマスネグラス  牡2  51.0  団野大成  1:50.9      5   46.6
# 201901010101   4   8   9     キタノコドウ  牡2  51.0  菅原明良  1:51.5  3.1/2   56.8
# 201901010101   5   5   5   ネモフィラブルー  牡2  54.0  川島信二  1:51.7  1.1/2  140.3
# ...           ..  ..  ..        ...  ..   ...   ...     ...    ...    ...
# 201910021212  12   6  11   スリープレッピー  セ6  56.0  森裕太朗  2:45.7    1/2  120.3
# 201910021212  13   1   1    バリオラージュ  牡5  54.0   斎藤新  2:46.0  1.3/4    7.5
# 201910021212  14   2   3  サンライズアミーゴ  牡4  54.0  亀田温心  2:46.2      1   99.2
# 201910021212  15   6  12        トロハ  牝3  52.0    武豊  2:46.2     クビ   17.5
# 201910021212  16   2   4   ダイシンステルラ  牝4  55.0  川須栄彦  2:47.0      5  110.3
#
#                 人気       馬体重       調教師 course_len weather race_type  \
# ...

# %% [markdown]
# ### 馬体重を体重と増減に分ける

# %%
results２['体重'] = results2['馬体重'].str.split('(', expand=True)[0].astype(int)
# Out:
# /var/folders/p9/g996fg895cs0zrq0v3h2273m0000gn/T/ipykernel_35932/2434321716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results２['体重'] = results2['馬体重'].str.split('(', expand=True)[0].astype(int)

# %%
results2['増減'] = results2['馬体重'].str.split('(', expand=True)[1].str[:-1].astype(int)
# Out:
# /var/folders/p9/g996fg895cs0zrq0v3h2273m0000gn/T/ipykernel_35932/3144097816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results2['増減'] = results2['馬体重'].str.split('(', expand=True)[1].str[:-1].astype(int)

# %% [markdown]
# ### 着順を整数型に変換

# %%
results2['着順'] = results2['着順'].astype(int)
# Out:
# /var/folders/p9/g996fg895cs0zrq0v3h2273m0000gn/T/ipykernel_35932/903033197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results2['着順'] = results2['着順'].astype(int)

# %% [markdown]
# ### 処理前の性齢と馬体重データを削除

# %%
results2.drop(['性齢','馬体重'], axis=1, inplace=True)
# Out:
# /Users/tak/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
results2
# Out:
#               着順  枠番  馬番         馬名    斤量    騎手     タイム     着差     単勝    人気  \
# 201901010101   1   1   1      ゴルコンダ  54.0  ルメール  1:48.3    NaN    1.4   1.0
# 201901010101   2   3   3   プントファイヤー  54.0  岩田康誠  1:50.1      大    3.5   2.0
# 201901010101   3   4   4  ラグリマスネグラス  51.0  団野大成  1:50.9      5   46.6   6.0
# 201901010101   4   8   9     キタノコドウ  51.0  菅原明良  1:51.5  3.1/2   56.8   7.0
# 201901010101   5   5   5   ネモフィラブルー  54.0  川島信二  1:51.7  1.1/2  140.3   9.0
# ...           ..  ..  ..        ...   ...   ...     ...    ...    ...   ...
# 201910021212  12   6  11   スリープレッピー  56.0  森裕太朗  2:45.7    1/2  120.3  15.0
# 201910021212  13   1   1    バリオラージュ  54.0   斎藤新  2:46.0  1.3/4    7.5   4.0
# 201910021212  14   2   3  サンライズアミーゴ  54.0  亀田温心  2:46.2      1   99.2  12.0
# 201910021212  15   6  12        トロハ  52.0    武豊  2:46.2     クビ   17.5   8.0
# 201910021212  16   2   4   ダイシンステルラ  55.0  川須栄彦  2:47.0      5  110.3  14.0
#
# ...

# %%
results2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47118 entries, 201901010101 to 201910021212
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   着順            47118 non-null  int64
#  1   枠番            47118 non-null  int64
#  2   馬番            47118 non-null  int64
#  3   馬名            47118 non-null  object
#  4   斤量            47118 non-null  float64
#  5   騎手            47118 non-null  object
#  6   タイム           47118 non-null  object
#  7   着差            43668 non-null  object
#  8   単勝            47118 non-null  object
#  9   人気            47118 non-null  float64
#  10  調教師           47118 non-null  object
#  11  course_len    47118 non-null  object
#  12  weather       47118 non-null  object
#  13  race_type     47118 non-null  object
#  14  ground_state  47118 non-null  object
#  15  date          47118 non-null  object
#  16  性             47118 non-null  object
# ...

# %% [markdown]
# ### 上記までの処理をまとめた関数を定義

# %%
import datetime

def preprocessing(results):
    df = results.copy()
    # 着順が数値以外を取り除き、整数型に変換
    df = df[~df['着順'].astype(str).str.contains('\D')]
    # 性齢を分解
    df['性'] = df['性齢'].map(lambda x: str(x)[0])
    df['年齢'] = df['性齢'].map(lambda x: str(x)[1:])
    # 馬体重を体重と増減に分ける
    df['体重'] = df['馬体重'].str.split('(', expand=True)[0].astype(int)
    df['増減'] = df['馬体重'].str.split('(', expand=True)[1].str[:-1].astype(int)
    # 型変換
    df['着順'] = df['着順'].astype(int)
    df['単勝'] = df['単勝'].astype(float)
    
    df['date'] = pd.to_datetime(df['date'], format='%Y年%m月%d日')
    
    #不要な行を消す
    df.drop(['性齢','馬体重','着差','タイム','調教師'], axis=1, inplace=True)
    return df

# %%
test = preprocessing(results)

# %% [markdown]
# ### 処理後のデータをファイルへ保存

# %%
save_file_name = target_year + '_result.pickle'
test.to_pickle(save_file_name)

# %%
test
# Out:
#               着順  枠番  馬番         馬名    斤量    騎手     単勝    人気 course_len  \
# 201901010101   1   1   1      ゴルコンダ  54.0  ルメール    1.4   1.0       1800
# 201901010101   2   3   3   プントファイヤー  54.0  岩田康誠    3.5   2.0       1800
# 201901010101   3   4   4  ラグリマスネグラス  51.0  団野大成   46.6   6.0       1800
# 201901010101   4   8   9     キタノコドウ  51.0  菅原明良   56.8   7.0       1800
# 201901010101   5   5   5   ネモフィラブルー  54.0  川島信二  140.3   9.0       1800
# ...           ..  ..  ..        ...   ...   ...    ...   ...        ...
# 201910021212  12   6  11   スリープレッピー  56.0  森裕太朗  120.3  15.0       2600
# 201910021212  13   1   1    バリオラージュ  54.0   斎藤新    7.5   4.0       2600
# 201910021212  14   2   3  サンライズアミーゴ  54.0  亀田温心   99.2  12.0       2600
# 201910021212  15   6  12        トロハ  52.0    武豊   17.5   8.0       2600
# 201910021212  16   2   4   ダイシンステルラ  55.0  川須栄彦  110.3  14.0       2600
#
#              weather race_type ground_state       date  性 年齢   体重  増減
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47118 entries, 201901010101 to 201910021212
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   着順            47118 non-null  int64
#  1   枠番            47118 non-null  int64
#  2   馬番            47118 non-null  int64
#  3   馬名            47118 non-null  object
#  4   斤量            47118 non-null  float64
#  5   騎手            47118 non-null  object
#  6   単勝            47118 non-null  float64
#  7   人気            47118 non-null  float64
#  8   course_len    47118 non-null  object
#  9   weather       47118 non-null  object
#  10  race_type     47118 non-null  object
#  11  ground_state  47118 non-null  object
#  12  date          47118 non-null  datetime64[ns]
#  13  性             47118 non-null  object
#  14  年齢            47118 non-null  object
#  15  体重            47118 non-null  int64
#  16  増減            47118 non-null  int64
# ...
